# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
out_dir = "/home/gaurav/Projects/DMRG_HK/output/"

with open(out_dir+"2D_OHK_DMRG_20240620-150253.pkl", "rb") as input_file:
    data_dict = pickle.load(input_file)

# %%
GS_list = data_dict['GS_list']
Lx_list = data_dict['Lx_list'] 
Ly_list = data_dict['Ly_list'] 
U = data_dict['U']
t = data_dict['t']
mu = data_dict['mu']
chi_max = data_dict['chi_max']
sweeps = data_dict['sweeps'] 
duration = data_dict['duration']
k_num = data_dict['k_num']

# %%
for j, Ly in enumerate(Ly_list):
    plt.scatter(Lx_list, GS_list[:, j], label="Ly="+str(Ly))
    
plt.legend()
plt.xlabel("Lx")
# Out:
# Text(0.5, 0, 'Lx')
